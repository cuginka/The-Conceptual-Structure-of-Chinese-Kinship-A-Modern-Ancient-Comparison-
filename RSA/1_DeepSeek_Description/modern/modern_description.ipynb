# %%
import pandas as pd
import numpy as np
import os

import time
import json

import openai
#import tiktoken
from dotenv import load_dotenv
load_dotenv()
from openai import OpenAI

api_key = os.getenv("DEEPSEEK_API_KEY")
client = OpenAI(api_key=api_key, base_url="https://api.deepseek.com/v1")

# %%
def askDeepSeek(messages):
    MODEL = "deepseek-chat"
    response = client.chat.completions.create(
        model= MODEL,
        messages=messages,
        temperature=0,
        stream=False ) # for replication
    return response.choices[0].message.content  # type: ignore


def get_arr(a):
    init = [{
        "role": "user",
        "content": a
    }]
    return init

# %%
rels_df  = pd.read_excel('./relationships.xlsx')
modern_142r = list(rels_df.loc[:,'query'])
modern_142r[0:5]
# Out:
# ['夫妻之间', '父子之间', '父女之间', '母子之间', '母女之间']

# %%
askDeepSeek(get_arr('你好！'))
# Out:
# '你好！很高兴见到你！😊 我是DeepSeek，由深度求索公司创造的AI助手。无论你有什么问题、需要什么帮助，或者只是想聊聊天，我都很乐意为你提供支持！\n\n我可以帮你解答各种问题，协助处理文档，进行创作和分析等等。而且我是完全免费的哦！有什么我可以为你做的吗？'

# %%
# Iterating through the list of relationships in groups of five.
for i in range(0, 5, 5):
    # Fetching the list of relationships for the current group.
    relationships = modern_142r[i:i+5]

    # Create prompt
    prompt = """请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：\n"""
    prompt += '\n'.join(relationships)
    prompt += "\n----\n请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。"

    print(prompt)
    
    # Obtaining the results.
    result = askDeepSeek(get_arr(prompt))
    with open(os.path.join('./archieve/example.txt'),'w',encoding='utf-8') as file_group:
         file_group.write(result)
# Out:
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 夫妻之间
# 父子之间
# 父女之间
# 母子之间
# 母女之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。

# %%
# Iterating through the list of relationships in groups of five.
for i in range(0, 5, 5):
    # Fetching the list of relationships for the current group.
    relationships = modern_142r[i:i+5]

    # Create prompt
    prompt = """请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：\n"""
    prompt += '\n'.join(relationships)
    prompt += "\n----\n请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。"

    print(prompt)
    
    # Obtaining the results.
    result = askDeepSeek(get_arr(prompt))
    with open(os.path.join('./archieve/example1.txt'),'w',encoding='utf-8') as file_group:
         file_group.write(result)
# Out:
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 夫妻之间
# 父子之间
# 父女之间
# 母子之间
# 母女之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。

# %%
# Iterating through the list of relationships in groups of five.
for i in range(0, len(modern_142r), 5):
    # Fetching the list of relationships for the current group.
    relationships = modern_142r[i:i+5]

    # Create prompt
    prompt = """请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：\n"""
    prompt += '\n'.join(relationships)
    prompt += "\n----\n请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。"

    print(prompt)
    
    # Obtaining the results.
    result = askDeepSeek(get_arr(prompt))
    with open(os.path.join('./archieve/',str(i)+'.txt'),'w',encoding='utf-8') as file_group:
         file_group.write(result)
# Out:
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 夫妻之间
# 父子之间
# 父女之间
# 母子之间
# 母女之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 兄弟之间
# 兄妹之间
# 姐弟之间
# 姐妹之间
# 祖父孙子之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 祖父孙女之间
# 祖母孙子之间
# 祖母孙女之间
# 外祖父外孙子之间
# 外祖父外孙女之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 外祖母外孙子之间
# 外祖母外孙女之间
# 曾祖父曾孙子之间
# 曾祖父曾孙女之间
# 曾祖母曾孙子之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 曾祖母曾孙女之间
# 高祖父玄孙之间
# 高祖母玄孙之间
# 外曾祖父外曾孙之间
# 外曾祖母外曾孙之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 祖先后代之间
# 伯父侄子之间
# 伯父侄女之间
# 伯母侄子之间
# 伯母侄女之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 叔父侄子之间
# 叔父侄女之间
# 叔母侄子之间
# 叔母侄女之间
# 姑父侄子之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 姑父侄女之间
# 姑母侄子之间
# 姑母侄女之间
# 舅父外甥之间
# 舅父外甥女之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 舅母外甥之间
# 舅母外甥女之间
# 姨父外甥之间
# 姨父外甥女之间
# 姨母外甥之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 姨母外甥女之间
# 堂兄堂弟之间
# 堂兄堂妹之间
# 堂姐堂弟之间
# 堂姐堂妹之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 表兄表弟之间
# 表兄表妹之间
# 表姐表弟之间
# 表姐表妹之间
# 姑表兄姑表弟之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 姑表兄姑表妹之间
# 姑表姐姑表弟之间
# 姑表姐姑表妹之间
# 舅表兄舅表弟之间
# 舅表兄舅表妹之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 舅表姐舅表弟之间
# 舅表姐舅表妹之间
# 姨表兄姨表弟之间
# 姨表兄姨表妹之间
# 姨表姐姨表弟之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 姨表姐姨表妹之间
# 岳父女婿之间
# 岳母女婿之间
# 公公儿媳之间
# 婆婆儿媳之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 舅父甥媳之间
# 舅父甥女婿之间
# 伯父侄媳之间
# 伯父侄女婿之间
# 姐夫妻弟之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 妹夫妻兄之间
# 妹夫妻姐之间
# 叔嫂之间
# 姑嫂之间
# 弟媳伯之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 兄妻弟妻之间
# 姐夫妹夫之间
# 亲家亲家之间
# 从祖父从孙子之间
# 从祖父从孙女之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 从祖母从孙子之间
# 从祖母从孙女之间
# 从祖姑从侄孙之间
# 再从兄再从弟之间
# 三从兄三从弟之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 堂伯堂侄之间
# 表叔表侄之间
# 族伯叔族侄之间
# 族兄族弟之间
# 族姐族妹之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 堂祖父堂侄孙之间
# 堂祖母堂侄孙之间
# 堂姐夫堂内弟之间
# 表嫂表小叔之间
# 姻伯叔姻侄之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 舅公甥孙之间
# 姨婆姨甥孙之间
# 继祖父继孙子之间
# 继祖父继孙女之间
# 继祖母继孙子之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 继祖母继孙女之间
# 继外祖父继外孙子之间
# 继外祖父继外孙女之间
# 继外祖母继外孙子之间
# 继外祖母继外孙女之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 继父继子之间
# 继父继女之间
# 继母继子之间
# 继母继女之间
# 继兄继弟之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 继兄继妹之间
# 继姐继弟之间
# 继姐继妹之间
# 养父养子之间
# 养父养女之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 养母养子之间
# 养母养女之间
# 义父义子之间
# 义父义女之间
# 义母义子之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 义母义女之间
# 干爹干儿子之间
# 干爹干女儿之间
# 干妈干儿子之间
# 干妈干女儿之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 同父异母兄同父异母弟之间
# 同父异母姐同父异母妹之间
# 同父异母兄同父异母妹之间
# 同父异母姐同父异母弟之间
# 同母异父兄同母异父弟之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 同母异父姐同母异父妹之间
# 同母异父兄同母异父妹之间
# 同母异父姐同母异父弟之间
# 异父异母兄异父异母弟之间
# 异父异母姐异父异母妹之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。
# 请你在当代中国的社会文化背景下，描述一些人际关系属性，呈现它的内涵和特点。现在我将提供关系列表，请你依次返回对它们关系性质的描述：
# 异父异母兄异父异母妹之间
# 异父异母姐异父异母弟之间
# ----
# 请返回json格式结果，以关系名为key，关系描述为value，如{‘父母和孩子’:{‘描述’:内容}}。

# %%
def parse_json_markdown(text):
    # 移除 ```json 和 结尾的 ```，并去除首尾空格
    clean_text = text.replace("```json", "").replace("```", "").strip()
    return json.loads(clean_text)

# %%
files = os.listdir('./archieve/')
df = pd.DataFrame({'prompt':[],'relation':[],'description':[]})
for i in range(0, len(modern_142r), 5):
    relationships = modern_142r[i:i+5]
    archive_path = './archieve/'+str(i)+'.txt'
    with open(archive_path, 'r', encoding='utf-8') as f:
        content = f.read()
        archieve_results = parse_json_markdown(content)
        temp_df = pd.DataFrame(archieve_results).transpose()
        temp_df.columns = ['description']
        temp_df.insert(0, 'relation', temp_df.index)
        temp_df.insert(0, 'prompt', relationships)
        df = pd.concat([df, temp_df], ignore_index=True)
df.to_csv('./modern_results.csv',encoding='gb18030')
